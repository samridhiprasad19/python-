# %%
import calendar
print(calendar.firstweekday())
print(calendar.weekday(2018,6,21))
# Out:
# 0
# 3

# %%
l = input().split()

print(l)
# Out:
# 12 45 76 19
# ['12', '45', '76', '19']

# %%
import string
alpha = string.ascii_lowercase

n = int(input())
L = []
for i in range(n):
    s = "-".join(alpha[i:n])
    L.append((s[::-1]+s[1:]).center(4*n-3, "-"))
print('\n'.join(L[:0:-1]+L))
# Out:
# 3
# ----c----
# --c-b-c--
# c-b-a-b-c
# --c-b-c--
# ----c----

# %%
s = 'hello'
pr'-'.join(s[0:2]))
# Out:
# h-e

# %%
s = 'something'
x = len(s)//3
r = 0
for i in range(1,x+1):
    c  =i*3
    print(s[r:c])
    r = c
# Out:
# som
# eth
# ing

# %%
12//3
# Out:
# 4

# %%
def unique_list(l):
    ulist = []
    [ulist.append(x) for x in l if x not in ulist]
    return ulist

# %%
a="AAF"
print(''.join(unique_list(a)))
# Out:
# AF

# %%
def unique_list(l):
    ulist = []
    [ulist.append(x) for x in l if x not in ulist]
    return ulist
def merge_the_tools(string, k):
    x = len(string)//k
    r = 0
    for i in range(1,x+1):
        c  =i*3             
        print(''.join(unique_list(string[r:c])))
        r = c

# %%
string, k = input(), int(input())
merge_the_tools(string, k)
# Out:
# ...,3452
# ...,3452
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-2e7f210eacf7> in <module>()
# ----> 1 string, k = input(), int(input())
#       2 merge_the_tools(string, k)
#
# ValueError: invalid literal for int() with base 10: 'KYQYTWXTDQXWDLKIXNWIITFBLIHRNGDZGVYCRXVWNUVSFFACUXMCSTFFBNWQVBQCWOEPNBOAVJUCOUGITSMNLSUOFRFAUXETNIKAJYCEJWIXSOHMGUBTOWKVPPXJOCEBKPDWNFCXDLWVZEJIALBOJLLYCIJQKOTXDWTSDVRIGOEIUPQUCRKLFVLHFXASNVPSUKKXHCG
